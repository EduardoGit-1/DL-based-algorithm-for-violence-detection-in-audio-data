# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,20)
plt.rcParams["font.family"] = "sans-serif"
CURRENT_HANAU = "Hanau03"
DATASET_DIR = "data_understanding/dataset_results/{}.csv".format(CURRENT_HANAU)
DATASET_DIR = r"D:\Projects\shared_repo\data_understanding\metadata\dataset_results\Hanau02_03.csv"
print(DATASET_DIR)
# Out:
# D:\Projects\shared_repo\data_understanding\metadata\dataset_results\Hanau02_03.csv

# %%
df = pd.read_csv(DATASET_DIR, index_col=0)

df = df[["Duration", "Label", "Type"]]
df
# Out:
#         Duration                       Label                     Type
# 0           7.40        normal_nointeraction  scene_activities_noises
# 1          12.80          normal_interaction  scene_activities_noises
# 2          11.40        normal_nointeraction  scene_activities_noises
# 3           2.00          normal_interaction  scene_activities_noises
# 4          10.20        normal_nointeraction  scene_activities_noises
# ...          ...                         ...                      ...
# 210448      0.90    neutral_emotion_backseat                  emotion
# 210449      0.40    neutral_emotion_backseat                  emotion
# 210450      1.80  positive_emotion_frontseat                  emotion
# 210451      0.80    neutral_emotion_backseat                  emotion
# 210452      1.17  positive_emotion_frontseat                  emotion
#
# [210453 rows x 3 columns]

# %%
temp_df = df.loc[df["Type"] == "speaker_aggressiveness"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60) /60
temp_df
ax = temp_df.plot(kind='bar', title='Speaker Aggressiveness Labels',
               ylabel='Duration (Hours)', figsize=(20, 10), legend = False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

ax.tick_params(bottom=False, left=False)

ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Speaker Aggressiveness Labels', fontsize=25)
ax.set_ylabel('Duration (Hours)', fontsize=18)
plt.xticks(rotation=0, fontsize = 18)
plt.xlabel("")
ax.figure.savefig("images/speaker_agg_labels.jpeg".format(CURRENT_HANAU), bbox_inches="tight")
#plt.savefig("images/{}/speaker_agg_labels.png".format(CURRENT_HANAU))

# %%
temp_df = df.loc[df["Type"] == "speaker_event"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration", ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60)
temp_df
ax = temp_df.plot(kind='bar', title='Speaker Events',
               ylabel='Duration (Minutes)', figsize=(20, 10), legend = False)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Speaker Events', fontsize=25)
ax.set_ylabel('Duration (Minutes)', fontsize=18)
plt.xticks(rotation=0, fontsize = 14)
plt.xlabel("")
plt.savefig("images/speaker_events.jpeg", bbox_inches="tight")

# %%
temp_df = df.loc[df["Type"] == "physical_violence_noises"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60) 
temp_df
ax = temp_df.plot(kind='bar', title='Physical Violence Noises',
               ylabel='Duration (Minutes)',figsize=(20, 10), legend = False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Physical Violence Noises', fontsize=25)
ax.set_ylabel('Duration (Minutes)', fontsize=18)
plt.xticks(rotation=0, fontsize = 16)
plt.xlabel("")
plt.savefig("images/phys_violence_noises.jpeg".format(CURRENT_HANAU), bbox_inches="tight")

# %%
temp_df = df.loc[df["Type"] == "background_noise"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60) / 60
temp_df
ax = temp_df.plot(kind='bar', title='Background Noises',
               ylabel='Duration (Hours)', figsize=(20, 10), legend = False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Background Noises', fontsize=25)
ax.set_ylabel('Duration (Hours)', fontsize=18)
plt.xticks(rotation=90, fontsize = 18)
plt.xlabel("")
plt.savefig("images/back_noises.jpeg".format(CURRENT_HANAU), bbox_inches="tight")

# %%
temp_df = df.loc[df["Type"] == "scene_activities_noises"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60) / 60
temp_df
ax = temp_df.plot(kind='bar', title='Scene Acitvity Noises',
               ylabel='Duration (Hours)', figsize=(20, 10), legend = False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Scene Acitvity Noises', fontsize=25)
ax.set_ylabel('Duration (Hours)', fontsize=18)
plt.xticks(rotation=90, fontsize = 18)
plt.xlabel("")
plt.savefig("images/scene_activity_noises.jpeg".format(CURRENT_HANAU), bbox_inches="tight")

# %%
temp_df = df.loc[df["Type"] == "silence"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60 / 60) 
temp_df
ax = temp_df.plot(kind='bar', title='Silence',
               ylabel='Duration (Minutes)', figsize=(10, 10), legend = False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Silence', fontsize=25)
ax.set_ylabel('Duration (Hours)', fontsize=18)
plt.xticks(rotation=0, fontsize = 18)
plt.xlabel("")
plt.savefig("images/silence.jpeg".format(CURRENT_HANAU), bbox_inches="tight")

# %%
temp_df = df.loc[df["Type"] == "emotion"]
temp_df = temp_df.groupby(["Label"]).sum().sort_values(by="Duration",ascending=False)
temp_df["Duration"] = (temp_df["Duration"] / 60) / 60
temp_df
ax = temp_df.plot(kind='bar', title='Scene classification',
               ylabel='Duration (Hours)', figsize=(20, 10), legend = False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')

# Second, remove the ticks as well.
ax.tick_params(bottom=False, left=False)

# Third, add a horizontal grid (but keep the vertical grid hidden).
# Color the lines a light gray as well.
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)
ax.set_title('Scene classification', fontsize=25)
ax.set_ylabel('Duration (Hours)', fontsize=18)
plt.xticks(rotation=0, fontsize = 12)
plt.xlabel("")
plt.savefig("images/scene_classification.jpeg".format(CURRENT_HANAU), bbox_inches="tight")

# %%
scene_noises_df = df.loc[df["Type"] == "scene_activities_noises"]
scene_noises_df
# Out:
#         Duration                 Label                     Type
# 0           7.40  normal_nointeraction  scene_activities_noises
# 1          12.80    normal_interaction  scene_activities_noises
# 2          11.40  normal_nointeraction  scene_activities_noises
# 3           2.00    normal_interaction  scene_activities_noises
# 4          10.20  normal_nointeraction  scene_activities_noises
# ...          ...                   ...                      ...
# 210287     38.00      anomaly_violence  scene_activities_noises
# 210288      7.23     anomaly_uncertain  scene_activities_noises
# 210386     49.00  anomaly_conversation  scene_activities_noises
# 210387     13.00   anomaly_interaction  scene_activities_noises
# 210388     24.17      anomaly_violence  scene_activities_noises
#
# [34678 rows x 3 columns]

# %%
len(scene_noises_df["Label"].unique())
# Out:
# 21
